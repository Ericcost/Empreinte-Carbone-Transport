# %% [markdown]
# # GES en Europe

# %% [markdown]
# ![Texte alternatif](874F0385-1D82-4388-BA93-A9A5380AE5E8.webp)

# %% [markdown]
# Parmi les 5 grands secteurs d'émissions de CO2 dans l'UE seul le transport intérieur connaît une augmentation entre 1990 et 2019 (25%) tandis que les autres diminuent sur la même période. Nous avons donc orienté nos recherches exploratoires sur ce sujet là précisément pour chercher à le comprendre dans un premier temps puis si possible à terme à apporter des éléments de réponses pour l'expliquer.

# %% [markdown]
# ![Texte alternatif](0D633C46-37B2-4AA8-B901-C7557FCA725F.webp
# )

# %% [markdown]
# En 2019, d'ailleurs on peut voir la répartition des émissions de GES par mode de transport dans l'UE en 2019.
# Ce qu'on doit retenir ici c'est que les transports routiers représentent une grande majorité des emissions de gaz à effet de serre du secteur transport intérieur dans l'UE.

# %% [markdown]
# ![Texte alternatif](Répartition-des-émissions-de-GES-en-France-en-2018.png)

# %% [markdown]
# Dans ce contexte Européen on a voulu faire un zoom sur la France pour découvrir ce qu'il en était à notre échelle. En 2018, on s'aperçoit que le transport représente la plus grosse part des émissions de gaz à effet de serre (30%).
# Plusieurs questions viennent alors à se poser :
# - Quels transports sont concernés ? Quelles sont les émissions produites selon les types de transports à l'échelle française ?
# - Quelle est la tendance de ces émissions de CO2 liés au Transport en France au fil du temps ?
# - Quelle est la variation de ces émissions selon les territoires (régions, départements) ?

# %% [markdown]
# # Emission CO2 Transports France et International

# %%
# !pip install geopandas
# Out:
# Requirement already satisfied: geopandas in /Users/ericcosterousse/.pyenv/versions/3.11.0/lib/python3.11/site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.22 in /Users/ericcosterousse/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from geopandas) (1.24.4)
# Requirement already satisfied: pyogrio>=0.7.2 in /Users/ericcosterousse/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in /Users/ericcosterousse/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from geopandas) (23.2)
# Requirement already satisfied: pandas>=1.4.0 in /Users/ericcosterousse/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from geopandas) (2.0.3)
# Requirement already satisfied: pyproj>=3.3.0 in /Users/ericcosterousse/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from geopandas) (3.7.0)
# Requirement already satisfied: shapely>=2.0.0 in /Users/ericcosterousse/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from geopandas) (2.0.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ericcosterousse/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/ericcosterousse/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/ericcosterousse/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: certifi in /Users/ericcosterousse/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from pyogrio>=0.7.2->geopandas) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /Users/ericcosterousse/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)

# %%
# Importation des bibliothèques nécessaires
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import geopandas as gpd

# %%
pd.set_option('display.width', 200)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

df = pd.read_csv("emission-co2-perimetre-complet (1).csv", sep = ';')

# %%
df["Train"] = df['Train_Empreinte carbone (kgCO2e)'] / df["Distance entre les gares"]
df["Bus"] = df['Autocar longue distance - Empreinte carbone (kgCO2e)'] / df['Distance entre les gares']
df["Voiture thermique"] = df['Voiture thermique (2,2 pers.)_Empreinte carbone (kgCO2e)'] / df['Distance entre les gares']
df["Voiture electrique"] = df['Voiture électrique (2,2 pers.) - Empreinte carbone (kgCO2e)'] / df['Distance entre les gares']
df["Avion"] = df['Avion_Empreinte carbone (kgCO2e)'] / df["Distance entre les gares"]

df["Trajet"] = df["Origine"] + " - " + df["Destination"]

# %%
# Fonction de coloration
def highlight_columns(column):
    return ['background-color: yellow' if column.name in ["Train", "Bus", "Voiture thermique", "Voiture electrique", "Avion"] else '' for _ in column]

# Appliquer le style au DataFrame
styled_df = df.style.apply(highlight_columns, axis=0)

# Affichage
styled_df
# Out:
# <style type="text/css">
# #T_cd29b_row0_col11, #T_cd29b_row0_col12, #T_cd29b_row0_col13, #T_cd29b_row0_col14, #T_cd29b_row0_col15, #T_cd29b_row1_col11, #T_cd29b_row1_col12, #T_cd29b_row1_col13, #T_cd29b_row1_col14, #T_cd29b_row1_col15, #T_cd29b_row2_col11, #T_cd29b_row2_col12, #T_cd29b_row2_col13, #T_cd29b_row2_col14, #T_cd29b_row2_col15, #T_cd29b_row3_col11, #T_cd29b_row3_col12, #T_cd29b_row3_col13, #T_cd29b_row3_col14, #T_cd29b_row3_col15, #T_cd29b_row4_col11, #T_cd29b_row4_col12, #T_cd29b_row4_col13, #T_cd29b_row4_col14, #T_cd29b_row4_col15, #T_cd29b_row5_col11, #T_cd29b_row5_col12, #T_cd29b_row5_col13, #T_cd29b_row5_col14, #T_cd29b_row5_col15, #T_cd29b_row6_col11, #T_cd29b_row6_col12, #T_cd29b_row6_col13, #T_cd29b_row6_col14, #T_cd29b_row6_col15, #T_cd29b_row7_col11, #T_cd29b_row7_col12, #T_cd29b_row7_col13, #T_cd29b_row7_col14, #T_cd29b_row7_col15, #T_cd29b_row8_col11, #T_cd29b_row8_col12, #T_cd29b_row8_col13, #T_cd29b_row8_col14, #T_cd29b_row8_col15, #T_cd29b_row9_col11, #T_cd29b_row9_col12, #T_cd29b_row9_col13, #T_cd29b_row9_col14, #T_cd29b_row9_col15, #T_cd29b_row10_col11, #T_cd29b_row10_col12, #T_cd29b_row10_col13, #T_cd29b_row10_col14, #T_cd29b_row10_col15, #T_cd29b_row11_col11, #T_cd29b_row11_col12, #T_cd29b_row11_col13, #T_cd29b_row11_col14, #T_cd29b_row11_col15, #T_cd29b_row12_col11, #T_cd29b_row12_col12, #T_cd29b_row12_col13, #T_cd29b_row12_col14, #T_cd29b_row12_col15, #T_cd29b_row13_col11, #T_cd29b_row13_col12, #T_cd29b_row13_col13, #T_cd29b_row13_col14, #T_cd29b_row13_col15, #T_cd29b_row14_col11, #T_cd29b_row14_col12, #T_cd29b_row14_col13, #T_cd29b_row14_col14, #T_cd29b_row14_col15, #T_cd29b_row15_col11, #T_cd29b_row15_col12, #T_cd29b_row15_col13, #T_cd29b_row15_col14, #T_cd29b_row15_col15, #T_cd29b_row16_col11, #T_cd29b_row16_col12, #T_cd29b_row16_col13, #T_cd29b_row16_col14, #T_cd29b_row16_col15, #T_cd29b_row17_col11, #T_cd29b_row17_col12, #T_cd29b_row17_col13, #T_cd29b_row17_col14, #T_cd29b_row17_col15, #T_cd29b_row18_col11, #T_cd29b_row18_col12, #T_cd29b_row18_col13, #T_cd29b_row18_col14, #T_cd29b_row18_col15, #T_cd29b_row19_col11, #T_cd29b_row19_col12, #T_cd29b_row19_col13, #T_cd29b_row19_col14, #T_cd29b_row19_col15, #T_cd29b_row20_col11, #T_cd29b_row20_col12, #T_cd29b_row20_col13, #T_cd29b_row20_col14, #T_cd29b_row20_col15, #T_cd29b_row21_col11, #T_cd29b_row21_col12, #T_cd29b_row21_col13, #T_cd29b_row21_col14, #T_cd29b_row21_col15, #T_cd29b_row22_col11, #T_cd29b_row22_col12, #T_cd29b_row22_col13, #T_cd29b_row22_col14, #T_cd29b_row22_col15, #T_cd29b_row23_col11, #T_cd29b_row23_col12, #T_cd29b_row23_col13, #T_cd29b_row23_col14, #T_cd29b_row23_col15, #T_cd29b_row24_col11, #T_cd29b_row24_col12, #T_cd29b_row24_col13, #T_cd29b_row24_col14, #T_cd29b_row24_col15, #T_cd29b_row25_col11, #T_cd29b_row25_col12, #T_cd29b_row25_col13, #T_cd29b_row25_col14, #T_cd29b_row25_col15, #T_cd29b_row26_col11, #T_cd29b_row26_col12, #T_cd29b_row26_col13, #T_cd29b_row26_col14, #T_cd29b_row26_col15, #T_cd29b_row27_col11, #T_cd29b_row27_col12, #T_cd29b_row27_col13, #T_cd29b_row27_col14, #T_cd29b_row27_col15, #T_cd29b_row28_col11, #T_cd29b_row28_col12, #T_cd29b_row28_col13, #T_cd29b_row28_col14, #T_cd29b_row28_col15, #T_cd29b_row29_col11, #T_cd29b_row29_col12, #T_cd29b_row29_col13, #T_cd29b_row29_col14, #T_cd29b_row29_col15, #T_cd29b_row30_col11, #T_cd29b_row30_col12, #T_cd29b_row30_col13, #T_cd29b_row30_col14, #T_cd29b_row30_col15, #T_cd29b_row31_col11, #T_cd29b_row31_col12, #T_cd29b_row31_col13, #T_cd29b_row31_col14, #T_cd29b_row31_col15, #T_cd29b_row32_col11, #T_cd29b_row32_col12, #T_cd29b_row32_col13, #T_cd29b_row32_col14, #T_cd29b_row32_col15, #T_cd29b_row33_col11, #T_cd29b_row33_col12, #T_cd29b_row33_col13, #T_cd29b_row33_col14, #T_cd29b_row33_col15, #T_cd29b_row34_col11, #T_cd29b_row34_col12, #T_cd29b_row34_col13, #T_cd29b_row34_col14, #T_cd29b_row34_col15, #T_cd29b_row35_col11, #T_cd29b_row35_col12, #T_cd29b_row35_col13, #T_cd29b_row35_col14, #T_cd29b_row35_col15, #T_cd29b_row36_col11, #T_cd29b_row36_col12, #T_cd29b_row36_col13, #T_cd29b_row36_col14, #T ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 19 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Transporteur                                                 119 non-null    object
#  1   Origine                                                      119 non-null    object
#  2   Origine_uic                                                  119 non-null    int64
#  3   Destination                                                  119 non-null    object
#  4   Destination_uic                                              119 non-null    int64
#  5   Distance entre les gares                                     119 non-null    float64
#  6   Train_Empreinte carbone (kgCO2e)                             119 non-null    float64
#  7   Autocar longue distance - Empreinte carbone (kgCO2e)         119 non-null    float64
#  8   Avion_Empreinte carbone (kgCO2e)                             38 non-null     float64
#  9   Voiture électrique (2,2 pers.) - Empreinte carbone (kgCO2e)  119 non-null    float64
#  10  Voiture thermique (2,2 pers.)_Empreinte carbone (kgCO2e)     119 non-null    float64
#  11  Train                                                        119 non-null    float64
#  12  Bus                                                          119 non-null    float64
#  13  Voiture thermique                                            119 non-null    float64
#  14  Voiture electrique                                           119 non-null    float64
#  15  Avion                                                        38 non-null     float64
#  16  Trajet                                                       119 non-null    object
#  17  Emission bus                                                 119 non-null    float64
#  18  Vol International                                            119 non-null    object
# dtypes: float64(12), int64(2), object(5)
# memory usage: 17.8+ KB

# %%
df.columns
# Out:
# Index(['Transporteur', 'Origine', 'Origine_uic', 'Destination', 'Destination_uic', 'Distance entre les gares', 'Train_Empreinte carbone (kgCO2e)',
#        'Autocar longue distance - Empreinte carbone (kgCO2e)', 'Avion_Empreinte carbone (kgCO2e)', 'Voiture électrique (2,2 pers.) - Empreinte carbone (kgCO2e)',
#        'Voiture thermique (2,2 pers.)_Empreinte carbone (kgCO2e)', 'Train', 'Bus', 'Voiture thermique', 'Voiture electrique', 'Avion', 'Trajet', 'Emission bus', 'Vol International'],
#       dtype='object')

# %%
# Methodes
## Camembert
def nombre_occurence_pie():
    transporteur_mean = df['Transporteur'].value_counts()


    plt.figure(figsize=(8, 8))
    plt.pie(
        transporteur_mean.values,
        labels=transporteur_mean.index,
        autopct='%1.1f%%',
        startangle=140,
        colors=sns.color_palette('viridis', len(transporteur_mean))
    )

    plt.title('Répartition des occurrences par transporteur', fontsize=14)

    plt.tight_layout()
    plt.show()

##
def trajets():

    fig = px.treemap(df, 
                  path=['Transporteur', 'Origine', 'Destination'], 
                  title='Émissions des trajets par transporteur et gares')

    fig.show()

##
def emission_moyenne():
    emissions_par_transporteur = df.groupby("Transporteur")["Train"].mean()
    emissions_par_transporteur_df = emissions_par_transporteur.reset_index()
    emissions_par_transporteur_df.columns = ["Transporteur", "Moyenne des émissions"]

    autocar = pd.DataFrame({
        "Transporteur": ["Autocar"],
        "Moyenne des émissions": [df["Bus"].mean()]
    })

    voitelec = pd.DataFrame({
        "Transporteur": ["Voiture electrique"],
        "Moyenne des émissions": [df["Voiture electrique"].mean()]
    })

    voither = pd.DataFrame({
        "Transporteur": ["Voiture thermique"],
        "Moyenne des émissions": [df["Voiture thermique"].mean()]
    })
        
    emissions_par_transporteur_df = pd.concat([emissions_par_transporteur_df, autocar], ignore_index=True)
    emissions_par_transporteur_df = pd.concat([emissions_par_transporteur_df, voitelec], ignore_index=True)
    emissions_par_transporteur_df = pd.concat([emissions_par_transporteur_df, voither], ignore_index=True)
    #print(emissions_par_transporteur_df)

    plt.figure(figsize=(10, 6))
    sns.barplot(
        x=emissions_par_transporteur_df["Transporteur"],
        y=emissions_par_transporteur_df["Moyenne des émissions"],
        palette="YlOrRd",
        legend = false
    )

    plt.title("Émissions calculées par transporteur", fontsize=16)
    plt.xlabel("Transporteur", fontsize=14)
    plt.ylabel("Émissions (kgCO2e / km)", fontsize=14)
    plt.xticks(rotation=45)
    plt.tight_layout()

    plt.show()

##
def emission_variance():
    emissions_par_transporteur = df.groupby("Transporteur")["Train"].var()

    plt.figure(figsize=(10, 6))
    sns.barplot(
        x=emissions_par_transporteur.index,
        y=emissions_par_transporteur.values,
        palette="Purples"
    )

    plt.title("Émissions calculées par transporteur", fontsize=16)
    plt.xlabel("Transporteur", fontsize=14)
    plt.ylabel("Émissions (kgCO2e / km)", fontsize=14)
    plt.xticks(rotation=45)
    plt.tight_layout()

    plt.show()

##
def avion_emission():

    vols_internationaux = ["Bruxelles Midi Brussel Zuid", "London St-Pancras", "Frankfurt Main HBF", "Milano P Garibaldi", "Amsterdam Centraal", "Barcelona Sants", "Luxembourg", "Torino Porta Susa", "Zuerich HB", "Muenchen HBF", "Geneve", "Schiphol Airport", "Stuttgart HBF", "Bruxelles N Aero", "Lausanne", "Basel SBB"]

    df["Vol International"] = df.apply(lambda x: "Oui" if x["Origine"] in vols_internationaux or x["Destination"] in vols_internationaux else "Non", axis=1)
    
    results = df.loc[df["Avion"].notnull(), ["Origine", "Destination", "Distance entre les gares", "Avion", "Vol International"]]

    print(results.sort_values(by="Avion", ascending=False))

    sns.scatterplot(
        data=results,
        x="Distance entre les gares",
        y="Avion",
        hue="Vol International",
        palette={"Oui": "red", "Non": "blue"},
        alpha=0.7
    )

    plt.title("Ratio d'émission avion en fonction de la distance (Vol International ou Non)")
    plt.xlabel("Distance entre les gares")
    plt.ylabel("Ratio d'émission avion")
    plt.legend(title="Vol International")
    plt.grid(True)
    plt.show()

##
def avion_train_voiture():

    df_long = df.loc[df["Avion"].notnull()]
    print(df_long[["Trajet", "Avion"]])


    df_long = df_long.melt(
        id_vars=["Trajet"],
        var_name="Mode de transport",
        value_name="Émissions (kgCO2e / km)"
    )

    df_long = df_long.loc[df_long["Mode de transport"].isin(["Train", "Bus", "Voiture electrique", "Voiture thermique", "Avion"])]
    ordre = ["Train", "Bus", "Voiture electrique", "Voiture thermique", "Avion"]

    sns.set(rc={'figure.autolayout': False})
    sns.set(style="whitegrid")

    g = sns.catplot(
        data=df_long,
        x="Mode de transport",
        y="Émissions (kgCO2e / km)",
        kind="violin",
        height=6,
        aspect=1.5,
        palette="viridis",
        inner=None,
        order=ordre
    )

    sns.swarmplot(data=df_long, x="Mode de transport", y="Émissions (kgCO2e / km)", size=3, color="white")

    g.set_xticklabels(rotation=0, fontsize=10)
    g.fig.suptitle("Émissions de gaz à effet de serre par trajet et mode de transport", fontsize=16)
    g.set_axis_labels("Trajet", "Émissions (kgCO2e / km)")

    plt.tight_layout()

    plt.show()

##
def train_voiture():

    df["Emission bus"] = df['Autocar longue distance - Empreinte carbone (kgCO2e)'] / df['Distance entre les gares']
    df["Voiture thermique"] = df['Voiture thermique (2,2 pers.)_Empreinte carbone (kgCO2e)'] / df['Distance entre les gares']
    df["Voiture electrique"] = df['Voiture électrique (2,2 pers.) - Empreinte carbone (kgCO2e)'] / df['Distance entre les gares']
    df["Trajet"] = df["Origine"] + " - " + df["Destination"]


    df_long = df.melt(
        id_vars=["Trajet"],
        var_name="Mode de transport",
        value_name="Émissions (kgCO2e / km)"
    )

    df_long = df_long.loc[df_long["Mode de transport"].isin(["Train", "Bus", "Voiture electrique", "Voiture thermique"])]
    ordre = ["Train", "Bus", "Voiture electrique", "Voiture thermique"]

    sns.set(rc={'figure.autolayout': False})
    sns.set(style="whitegrid")

    sns.stripplot(
        data=df_long,
        x="Mode de transport",
        y="Émissions (kgCO2e / km)",
        hue="Mode de transport",
        jitter=True,
        palette="viridis",
        order=ordre
    )
    plt.title("Émissions par Trajet et Mode de Transport", fontsize=16)
    plt.xlabel("Trajets", fontsize=12)
    plt.ylabel("Émissions (kgCO2e / km)", fontsize=12)
    plt.xticks(rotation=45)
    plt.show()

##
def ligne():
    df_long = df.melt(
        id_vars=["Distance entre les gares"],
        value_vars=["Train_Empreinte carbone (kgCO2e)", "Autocar longue distance - Empreinte carbone (kgCO2e)", "Avion_Empreinte carbone (kgCO2e)", "Voiture électrique (2,2 pers.) - Empreinte carbone (kgCO2e)", "Voiture thermique (2,2 pers.)_Empreinte carbone (kgCO2e)"],
        var_name="Mode de transport",
        value_name="Émissions (kgCO2e / km)"
    )

    plt.figure(figsize=(12, 8))
    sn = sns.lmplot(
        data=df_long, 
        x="Distance entre les gares", 
        y="Émissions (kgCO2e / km)", 
        hue="Mode de transport"
    )

    sn.legend.remove()
    plt.title("Émissions de CO2 par mode de transport en fonction de la distance", fontsize=16)
    plt.xlabel("Distance entre les gares (km)", fontsize=14)
    plt.ylabel("Émissions (kgCO2e / km)", fontsize=14)
    plt.legend(title="Mode de transport")
    plt.tight_layout()

    plt.show()

# %%
nombre_occurence_pie()

# %%
# emission_variance()

# %%
emission_moyenne()
# Out:
# /var/folders/5w/jbysldxx6d32vym0rw5yrssm0000gn/T/ipykernel_3549/3213093636.py:57: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
avion_emission()
# Out:
#                               Origine                  Destination  Distance entre les gares     Avion Vol International
# 106                Paris Montparnasse          Bordeaux Saint-Jean                   537.130  0.241337               Non
# 53                 Paris Gare de Lyon               Lyon Part Dieu                   429.496  0.238787               Non
# 16   Aéroport Charles de Gaulle 2 TGV               Lyon Part Dieu                   442.000  0.235566               Non
# 19                 Paris Gare de Lyon      Marseille Saint-Charles                   750.138  0.229716               Non
# 20                 Paris Gare de Lyon                       Toulon                   812.000  0.223114               Non
# 92                     Lyon Part Dieu      Marseille Saint-Charles                   325.000  0.221856               Non
# 81                   Strasbourg Ville                       Nantes                   834.000  0.221598               Non
# 18   Aéroport Charles de Gaulle 2 TGV  Bruxelles Midi Brussel Zuid                   291.000  0.215575               Oui
# 91                 Paris Gare de Lyon       Montpellier Saint-Roch                   738.861  0.209970               Non
# 14        Bruxelles Midi Brussel Zuid               Lyon Part Dieu                   733.000  0.201706               Oui
# 0                  Paris Montparnasse                       Rennes                   363.952  0.196079               Non
# 115                Paris Gare de Lyon                         Nice                   971.680  0.184574               Non
# 98                 Paris Montparnasse                     Biarritz                   744.496  0.128769               Non
# 38                 Paris Montparnasse                       Nantes                   385.841  0.126646               Non
# 74                         Paris Nord             Bruxelles N Aero                   314.000  0.120938               Oui
# 71                 Paris-Gare-de-Lyon             Clermont-Ferrand                   419.000  0.119018               Non
# 113                         Paris Est                Stuttgart HBF                   608.000  0.118552               Oui
# 37                         Paris Nord             Schiphol Airport                   510.000  0.118293               Oui
# 101                Paris Montparnasse                        Brest                   613.000  0.117585               Non
# 75                 Paris Gare de Lyon                       Geneve                   503.000  0.117375               Oui
# 55                          Paris Est                 Muenchen HBF                   843.000  0.116782               Oui
# 58                 Paris Gare de Lyon                   Zuerich HB                   614.000  0.114593               Oui
# 89                 Paris Gare de Lyon            Torino Porta Susa                   734.000  0.114406               Oui
# 68                          Paris Est                   Luxembourg                   373.000  0.113718               Oui
# 34                          Paris Est                     Mulhouse                   495.000  0.113482               Non
# 21                         Paris Nord           Amsterdam Centraal                   545.000  0.113325               Oui
# 87            Marseille Saint-Charles  Bruxelles Midi Brussel Zuid                  1072.000  0.112822               Oui
# 97   Aéroport Charles de Gaulle 2 TGV                       Rennes                   421.000  0.111985               Non
# 112  Aéroport Charles de Gaulle 2 TGV  Bruxelles Midi Brussel Zuid                   310.000  0.111404               Oui
# 103                Paris Gare de Lyon              Barcelona Sants                  1076.000  0.110804               Oui
# 69                   Paris-Austerlitz                        Rodez                   660.000  0.108995               Non
# 44                     Lyon Part Dieu  Bruxelles Midi Brussel Zuid                   751.000  0.108381               Oui
# 29            Marseille Saint-Charles          Bordeaux Saint-Jean                   680.000  0.106632               Non
# 7                  Paris Montparnasse            Toulouse Matabiau                   793.993  0.106303               Non
# 6                  Paris Gare de Lyon           Milano P Garibaldi                   877.000  0.104901               Oui
# 117                         Paris Est           Frankfurt Main HBF                   659.000  0.104594               Oui
# 51                         Paris Nord            London St-Pancras                   496.000  0.098808               Oui
# 93                     Lyon-Part-Dieu                       Nantes                   812.000  0.091063               Non

# %%
avion_train_voiture()
# Out:
#                                                 Trajet     Avion
# 0                          Paris Montparnasse - Rennes  0.196079
# 6              Paris Gare de Lyon - Milano P Garibaldi  0.104901
# 7               Paris Montparnasse - Toulouse Matabiau  0.106303
# 14        Bruxelles Midi Brussel Zuid - Lyon Part Dieu  0.201706
# 16   Aéroport Charles de Gaulle 2 TGV - Lyon Part Dieu  0.235566
# 18   Aéroport Charles de Gaulle 2 TGV - Bruxelles M...  0.215575
# 19        Paris Gare de Lyon - Marseille Saint-Charles  0.229716
# 20                         Paris Gare de Lyon - Toulon  0.223114
# 21                     Paris Nord - Amsterdam Centraal  0.113325
# 29       Marseille Saint-Charles - Bordeaux Saint-Jean  0.106632
# 34                                Paris Est - Mulhouse  0.113482
# 37                       Paris Nord - Schiphol Airport  0.118293
# 38                         Paris Montparnasse - Nantes  0.126646
# 44        Lyon Part Dieu - Bruxelles Midi Brussel Zuid  0.108381
# 51                      Paris Nord - London St-Pancras  0.098808
# 53                 Paris Gare de Lyon - Lyon Part Dieu  0.238787
# 55                            Paris Est - Muenchen HBF  0.116782
# 58                     Paris Gare de Lyon - Zuerich HB  0.114593
# 68                              Paris Est - Luxembourg  0.113718
# 69                            Paris-Austerlitz - Rodez  0.108995
# 71               Paris-Gare-de-Lyon - Clermont-Ferrand  0.119018
# 74                       Paris Nord - Bruxelles N Aero  0.120938
# 75                         Paris Gare de Lyon - Geneve  0.117375
# 81                           Strasbourg Ville - Nantes  0.221598
# 87   Marseille Saint-Charles - Bruxelles Midi Bruss...  0.112822
# 89              Paris Gare de Lyon - Torino Porta Susa  0.114406
# 91         Paris Gare de Lyon - Montpellier Saint-Roch  0.209970
# 92            Lyon Part Dieu - Marseille Saint-Charles  0.221856
# 93                             Lyon-Part-Dieu - Nantes  0.091063
# 97           Aéroport Charles de Gaulle 2 TGV - Rennes  0.111985
# 98                       Paris Montparnasse - Biarritz  0.128769
# 101                         Paris Montparnasse - Brest  0.117585
# 103               Paris Gare de Lyon - Barcelona Sants  0.110804
# 106           Paris Montparnasse - Bordeaux Saint-Jean  0.241337
# 112  Aéroport Charles de Gaulle 2 TGV - Bruxelles M...  0.111404
# 113                          Paris Est - Stuttgart HBF  0.118552
# 115                          Paris Gare de Lyon - Nice  0.184574
# 117                     Paris Est - Frankfurt Main HBF  0.104594
# /var/folders/5w/jbysldxx6d32vym0rw5yrssm0000gn/T/ipykernel_3549/127579835.py:136: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
ligne()

# %% [markdown]
# # Problématique : Quels modes de transports privilégiés pour limiter les émissions de GES ?
